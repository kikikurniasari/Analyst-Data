# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy.stats import normaltest, chi2_contingency, mannwhitneyu, ttest_ind

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Kali ini saya coba melihat data yang ada untuk melihat data apa saja yang tersedia, apakah terdapat missing value, bagaimana respon customer.

# %%
df=pd.read_csv('airline passanger satisfaction.csv')
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
display(df.head(),df.tail())
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0  70172   Male    Loyal Customer     13   Personal Travel  Eco Plus
# 1  5047    Male    disloyal Customer  25   Business travel  Business
# 2  110028  Female  Loyal Customer     26   Business travel  Business
# 3  24026   Female  Loyal Customer     25   Business travel  Business
# 4  119299  Male    Loyal Customer     61   Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0  460              3                      4
# 1  235              3                      2
# 2  1142             2                      2
# 3  562              2                      5
# 4  214              3                      3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# 0  3                       ...  5                       4
# 1  3                       ...  1                       1
# ...

# %%
print(f'Jumlah baris dan kolom di dataset df adalah {df.shape}')
df.info()
# Out:
# Jumlah baris dan kolom di dataset df adalah (103904, 24)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103904 non-null  int64
#  1   Gender                             103904 non-null  object
#  2   Customer Type                      103904 non-null  object
#  3   Age                                103904 non-null  int64
#  4   Type of Travel                     103904 non-null  object
#  5   Class                              103904 non-null  object
#  6   Flight Distance                    103904 non-null  int64
#  7   Inflight wifi service              103904 non-null  int64
#  8   Departure/Arrival time convenient  103904 non-null  int64
#  9   Ease of Online booking             103904 non-null  int64
# ...

# %%
display(df.describe(), df.describe(include='object'))
# Out:
#                   id            Age  Flight Distance  Inflight wifi service  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean   64924.210502   39.379706      1189.448375      2.729683
# std    37463.812252   15.114964      997.147281       1.327829
# min    1.000000       7.000000       31.000000        0.000000
# 25%    32533.750000   27.000000      414.000000       2.000000
# 50%    64856.500000   40.000000      843.000000       3.000000
# 75%    97368.250000   51.000000      1743.000000      4.000000
# max    129880.000000  85.000000      4983.000000      5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count  103904.000000                      103904.000000
# mean   3.060296                           2.756901
# std    1.525075                           1.398929
# min    0.000000                           0.000000
# 25%    2.000000                           2.000000
# ...

# %%
pd.set_option('display.max_colwidth', -1)
# data uni di tiap kolom
listItem = []
for col in df.columns :
    listItem.append( [col, df[col].nunique(), df[col].unique()])

tabel1Desc = pd.DataFrame(columns=['Column Name', 'Number of Unique', 'Unique Sample'],
                     data=listItem)
tabel1Desc
# Out:
#                           Column Name  Number of Unique  \
# 0   id                                 103904
# 1   Gender                             2
# 2   Customer Type                      2
# 3   Age                                75
# 4   Type of Travel                     2
# 5   Class                              3
# 6   Flight Distance                    3802
# 7   Inflight wifi service              6
# 8   Departure/Arrival time convenient  6
# 9   Ease of Online booking             6
# 10  Gate location                      6
# 11  Food and drink                     6
# 12  Online boarding                    6
# 13  Seat comfort                       6
# 14  Inflight entertainment             6
# 15  On-board service                   6
# 16  Leg room service                   6
# 17  Baggage handling                   5
# 18  Checkin service                    6
# 19  Inflight service                   6
# 20  Cleanliness                        6
# ...

# %%
# persentase missing value di tiap kolom
df.isna().sum()/df.shape[0]*100
# Out:
# id                                   0.000000
# Gender                               0.000000
# Customer Type                        0.000000
# Age                                  0.000000
# Type of Travel                       0.000000
# Class                                0.000000
# Flight Distance                      0.000000
# Inflight wifi service                0.000000
# Departure/Arrival time convenient    0.000000
# Ease of Online booking               0.000000
# Gate location                        0.000000
# Food and drink                       0.000000
# Online boarding                      0.000000
# Seat comfort                         0.000000
# Inflight entertainment               0.000000
# On-board service                     0.000000
# Leg room service                     0.000000
# Baggage handling                     0.000000
# Checkin service                      0.000000
# Inflight service                     0.000000
# ...

# %%
df[['Arrival Delay in Minutes']].isna().sum()
# Out:
# Arrival Delay in Minutes    310
# dtype: int64

# %%
df[df['Arrival Delay in Minutes'].isna()]
# Out:
#             id  Gender      Customer Type  Age   Type of Travel     Class  \
# 213     49608   Female  Loyal Customer     38   Business travel  Eco
# 1124    73442   Male    Loyal Customer     53   Personal Travel  Eco
# 1529    71178   Male    Loyal Customer     39   Business travel  Business
# 2004    72940   Female  disloyal Customer  26   Business travel  Business
# 2108    116374  Female  Loyal Customer     24   Personal Travel  Eco
# ...        ...     ...             ...     ..               ...  ...
# 102067  36729   Male    Loyal Customer     49   Personal Travel  Eco Plus
# 102384  71241   Male    Loyal Customer     58   Business travel  Eco
# 102552  27684   Female  disloyal Customer  29   Business travel  Eco
# 102960  36787   Male    Loyal Customer     58   Business travel  Eco
# 103540  45022   Female  Loyal Customer     33   Personal Travel  Eco
#
#         Flight Distance  Inflight wifi service  \
# 213     109              5
# 1124    1012             3
# ...

# %%
df.dropna(subset=['Arrival Delay in Minutes'],inplace=True)
df[['Arrival Delay in Minutes']].isna().sum()
# Out:
# Arrival Delay in Minutes    0
# dtype: int64

# %%
#DATA BERSIH


listItem = []
for col in df.columns :
    listItem.append([col, df[col].dtype, df[col].isna().sum(),
                    df[col].nunique(), list(df[col].drop_duplicates().sample(2).values)]);

dfDesc = pd.DataFrame(columns=['dataFeatures', 'dataType', 'null', 'unique', 'uniqueSample'],
                     data=listItem)
print(df.shape)
dfDesc
# Out:
# (103594, 24)
#                          dataFeatures dataType  null  unique  \
# 0   id                                 int64    0     103594
# 1   Gender                             object   0     2
# 2   Customer Type                      object   0     2
# 3   Age                                int64    0     75
# 4   Type of Travel                     object   0     2
# 5   Class                              object   0     3
# 6   Flight Distance                    int64    0     3802
# 7   Inflight wifi service              int64    0     6
# 8   Departure/Arrival time convenient  int64    0     6
# 9   Ease of Online booking             int64    0     6
# 10  Gate location                      int64    0     6
# 11  Food and drink                     int64    0     6
# 12  Online boarding                    int64    0     6
# 13  Seat comfort                       int64    0     6
# 14  Inflight entertainment             int64    0     6
# ...

# %%
df_ct=pd.crosstab(df['Customer Type'],df['satisfaction'])
df_ct['Total']=df_ct.sum(axis=1)
df_ct.sort_values('Total',ascending=False).head(10)
# Out:
# satisfaction       neutral or dissatisfied  satisfied  Total
# Customer Type
# Loyal Customer     44249                    40413      84662
# disloyal Customer  14448                    4484       18932

# %% [markdown]
# Dari keseluruhan data koresponden terbanyak adalah customer loyal dan kebanyakan merespon netral dan tidak puas dibandingkan dengan yang puas.
# Hal ini terjadi jg dengan customer biasa.
#
# yang menarik perhatian saya, kebanyakan dari pelayanan yang sudah diberikan, yang manakah yang lebih banyak? netral atau malah ketidaknyamanan.

# %%
ordinal_dict={5:'Excellent',
            4:'Very Good',
            3:'neutral',
            2:'Bad',
            1:'Very Bad',
            0:'Not reported'}

df['on-board_respon']=df['On-board service'].map(ordinal_dict)
df['on-board_respon'].value_counts()
# Out:
# Very Good       30773
# Excellent       23584
# neutral         22770
# Bad             14632
# Very Bad        11832
# Not reported    3
# Name: on-board_respon, dtype: int64

# %%
df['Inflight wifi service_respon']=df['Inflight wifi service'].map(ordinal_dict)
df['Inflight wifi service_respon'].value_counts(ascending=False)
# Out:
# neutral         25789
# Bad             25755
# Very Good       19737
# Very Bad        17781
# Excellent       11436
# Not reported    3096
# Name: Inflight wifi service_respon, dtype: int64

# %%
df['Departure/Arrival_time_convenient_respon']=df['Departure/Arrival time convenient'].map(ordinal_dict)
df['Departure/Arrival_time_convenient_respon'].value_counts()
# Out:
# Very Good       25474
# Excellent       22333
# neutral         17903
# Bad             17142
# Very Bad        15452
# Not reported    5290
# Name: Departure/Arrival_time_convenient_respon, dtype: int64

# %%
df['Gate location_respon']=df['Gate location'].map(ordinal_dict)
df['Gate location_respon'].value_counts()
# Out:
# neutral         28489
# Very Good       24353
# Bad             19396
# Very Bad        17511
# Excellent       13844
# Not reported    1
# Name: Gate location_respon, dtype: int64

# %%
df['Food and drink_respon']=df['Gate location'].map(ordinal_dict)
df['Food and drink_respon'].value_counts()
# Out:
# neutral         28489
# Very Good       24353
# Bad             19396
# Very Bad        17511
# Excellent       13844
# Not reported    1
# Name: Food and drink_respon, dtype: int64

# %%
df['Online boarding_respon']=df['Online boarding'].map(ordinal_dict)
df['Online boarding_respon'].value_counts()
# Out:
# Very Good       30671
# neutral         21744
# Excellent       20652
# Bad             17449
# Very Bad        10658
# Not reported    2420
# Name: Online boarding_respon, dtype: int64

# %%
df['Seat comfort_respon']=df['Seat comfort'].map(ordinal_dict)
df['Seat comfort_respon'].value_counts()
# Out:
# Very Good       31682
# Excellent       26393
# neutral         18641
# Bad             14846
# Very Bad        12031
# Not reported    1
# Name: Seat comfort_respon, dtype: int64

# %%
df['Inflight entertainment_respon']=df['Inflight entertainment'].map(ordinal_dict)
df['Inflight entertainment_respon'].value_counts()
# Out:
# Very Good       29335
# Excellent       25145
# neutral         19080
# Bad             17579
# Very Bad        12441
# Not reported    14
# Name: Inflight entertainment_respon, dtype: int64

# %%
df['On-board_service_respon']=df['On-board service'].map(ordinal_dict)
df['On-board_service_respon'].value_counts()
# Out:
# Very Good       30773
# Excellent       23584
# neutral         22770
# Bad             14632
# Very Bad        11832
# Not reported    3
# Name: On-board_service_respon, dtype: int64

# %%
df['Baggage handling_respon']=df['Baggage handling'].map(ordinal_dict)
df['Baggage handling_respon'].value_counts()
# Out:
# Very Good    37274
# Excellent    27047
# neutral      20567
# Bad          11483
# Very Bad     7223
# Name: Baggage handling_respon, dtype: int64

# %%
df['Leg room service_respon']=df['Leg room service'].map(ordinal_dict)
df['Leg room service_respon'].value_counts()
# Out:
# Very Good       28704
# Excellent       24599
# neutral         20042
# Bad             19469
# Very Bad        10310
# Not reported    470
# Name: Leg room service_respon, dtype: int64

# %%
df['Checkin service_respon']=df['Checkin service'].map(ordinal_dict)
df['Checkin service_respon'].value_counts()
# Out:
# Very Good       28975
# neutral         28356
# Excellent       20556
# Bad             12854
# Very Bad        12852
# Not reported    1
# Name: Checkin service_respon, dtype: int64

# %%
df['Inflight service_respon']=df['Inflight service'].map(ordinal_dict)
df['Inflight service_respon'].value_counts()
# Out:
# Very Good       37846
# Excellent       27041
# neutral         20227
# Bad             11414
# Very Bad        7063
# Not reported    3
# Name: Inflight service_respon, dtype: int64

# %%
df['Cleanliness_respon']=df['Cleanliness'].map(ordinal_dict)
df['Cleanliness_respon'].value_counts()
# Out:
# Very Good       27100
# neutral         24506
# Excellent       22619
# Bad             16081
# Very Bad        13276
# Not reported    12
# Name: Cleanliness_respon, dtype: int64

# %% [markdown]
# Kesimpulannya :
#
# Selama waktu penerbangan kali ini, banyak customer loyal yang menggunakan jasa kita dan respon dari mereka tidaklah buruk. walaupun sebanyak 52,27% merespon secara netral. Tetapi hal ini jauh lebih baik, dibandingkan jika ternyat performa pelayanan yg sudah diberikan menurun.
#
# Tiga pelayanan yang ternyata mendapatkan respon biasa saja dan jika di lihat kembali untuk respon 'Excellent' pada pelayanan ini terlihat lebih sedikit dibandingkan pelayanan yang lainnya, yakni Inflight wifi, Gate location, dan Food and drink.
# Disisi lain ada 1 pelayanan yang hampir mendapatkan banyak respon buruk yakni Inflight wifi. Terkait hal tersebut, mungkin bisa lebih diperhatikan ketersediaan fasilitas yang lebih mumpuni.
#
# Mungkin ada baiknya pelayanan disebutkan di atas bisa lebih di evaluasi kembali, dan ditingkatkan kualitasnya sehingga penilaian customer tidak menurun di bbrp tahun kedepan.
